# %% [markdown]
# <a href="https://colab.research.google.com/github/asantos20/Analise-Vendas/blob/main/Previs%C3%A3o_de_Vendas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Problema de Negócio:** Prever as vendas de um supermercado de acordo com as caractrísticas dos produtos.

# %%
# Importação das bibliotecas
import pandas as pd

# %%
# Importação das bibliotecas
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

# %%
# Importando os dados

base_train = pd.read_csv('/content/Dados/train.csv')
base_test = pd.read_csv('/content/Dados/test.csv')

# %%
# Base Treino
base_train.head()
# Out:
#    Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0     6.800000         0.037490   48.6034                       2004
# 1    15.600000         0.172597  114.8518                       1997
# 2    12.911575         0.054721  107.8254                       1985
# 3    11.800000         0.098312   81.4618                       1998
# 4    17.850000         0.046600  125.1388                       2004
#
#    Item_Outlet_Sales  Item_Fat_Content_LF  Item_Fat_Content_Low Fat  \
# 0           291.6204                    0                         1
# 1          2163.1842                    0                         1
# 2          2387.5588                    0                         1
# 3           161.1236                    0                         1
# 4          1981.4208                    0                         0
#
#    Item_Fat_Content_Regular  Item_Fat_Content_low fat  Item_Fat_Content_reg  \
# ...

# %%
# Shape

print('Shape base treinamento: ', base_train.shape)
print('Shape base treinamento: ', base_test.shape)
# Out:
# Shape base treinamento:  (1364, 36)
# Shape base treinamento:  (341, 36)

# %% [markdown]
# Foi desconsiderado o pre-processamento dos dados para deixar mais enxuto esse estudo. Em outro script será detalhada essa parte.
